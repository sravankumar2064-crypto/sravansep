# %%
import pandas as pd

# %%
# step-1: create data frame using list
names = ['Ramesh','Suresh','Sathish']

# %%
#pd.DataFrame(data,index,columns)

pd.DataFrame(names,columns=['Names'])
# Out:
#      Names
# 0   Ramesh
# 1   Suresh
# 2  Sathish

# %%
pd.DataFrame(names,index=['A','B','C'],columns=['Names'])
# Out:
#      Names
# A   Ramesh
# B   Suresh
# C  Sathish

# %%
#step-2
names = ['Ramesh','Suresh','Sathish']
age=[20,22,24]
#pd.DataFrame(data,index,columns)
pd.DataFrame(zip(names,age),columns = ['Names','Age'])
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
#step - 3 = create a dataframe using dict
d={'Names':['Ramesh','Suresh','Sathish'],
   'Age':[20,22,24]}
d
# Out:
# {'Names': ['Ramesh', 'Suresh', 'Sathish'], 'Age': [20, 22, 24]}

# %%
pd.DataFrame(d)
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
#step-4: selection updation and add column
#select the column
#update the column
#add new column

# %%
d={'Names':['Ramesh','Suresh','Sathish'],
   'Age':[20,22,24]}
df=pd.DataFrame(d)
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
#select the column
df['Names']
# Out:
# 0     Ramesh
# 1     Suresh
# 2    Sathish
# Name: Names, dtype: object

# %%
#update the column
df['Age']=[30,32,34]

# %%
df
# Out:
#      Names  Age
# 0   Ramesh   30
# 1   Suresh   32
# 2  Sathish   34

# %%
#add new column
df['City'] = ['Hyd','Blr','Pune']

# %%
df
# Out:
#      Names  Age  City
# 0   Ramesh   30   Hyd
# 1   Suresh   32   Blr
# 2  Sathish   34  Pune

# %%
#specific value
#inplace=we need to tell the python that output should be overwrite
df.replace('Suresh','Mahesh',inplace=True)

# %%
df
# Out:
#      Names  Age  City
# 0   Ramesh   30   Hyd
# 1   Mahesh   32   Blr
# 2  Sathish   34  Pune

# %%
#condition
import numpy as np
np.where()

# %%
df['Names'] == 'Mahesh'
# Out:
# 0    False
# 1     True
# 2    False
# Name: Names, dtype: bool

# %%
l = []
for i,j in zip(df['Names'],df['Age']):
    if i=='Mahesh':
        l.append(45)
    else:
        l.append(j)
l
df['Age'] = l

# %%
df
# Out:
#      Names  Age  City
# 0   Ramesh   30   Hyd
# 1   Mahesh   45   Blr
# 2  Sathish   34  Pune

# %%
import numpy as np
df['Age'] = np.where(df['Names']=='Mahesh',65,df['Age'])
df
# Out:
#      Names  Age  City
# 0   Ramesh   30   Hyd
# 1   Mahesh   65   Blr
# 2  Sathish   34  Pune

# %%
#How to drop a column
df
# Out:
#      Names  Age  City
# 0   Ramesh   30   Hyd
# 1   Mahesh   65   Blr
# 2  Sathish   34  Pune

# %%
#df.drop(labels,axis,index,column)
#by default axis=0, index
df.drop('City',axis=1) #inplace
# Out:
#      Names  Age
# 0   Ramesh   30
# 1   Mahesh   65
# 2  Sathish   34

# %%
df
# Out:
#      Names  Age  City
# 0   Ramesh   30   Hyd
# 1   Mahesh   65   Blr
# 2  Sathish   34  Pune

# %%
df.drop(columns=['City'])
# Out:
#      Names  Age
# 0   Ramesh   30
# 1   Mahesh   65
# 2  Sathish   34
